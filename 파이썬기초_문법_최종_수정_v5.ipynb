# %%
# 여긴 코드셀
# 아랜 텍스트셀

# %% [markdown]
# ### (여긴 텍스트 셀)
#
# # **파이썬 기초(Python Basic)**
#
# *   파이썬은 **사람이 읽기 쉬운 문법**을 목표로 만들어진 프로그래밍 언어
#
# *   1990년 네덜란드의 **귀도 반 로섬(Guido van Rossum)** 이 개발
#
# *   이름은 코미디쇼 *Monty Python’s Flying Circus* 에서 따옴
#
# *   현재 파이썬은
#   **웹 서비스**, **데이터 분석**, **AI·머신러닝**, **시각화** 등
#   매우 다양한 분야에서 사용되고 있음
#
# * 파이썬의 가장 큰 특징
#   - 코드를 **한 줄씩 바로 실행**하면서 결과를 확인할 수 있음
#   - 문법이 간단해 **전공자가 아니어도 접근 가능**
#
# * 우리는 오늘
#   - “프로그래머처럼 잘 짜는 법”이 아니라
#   - **코드를 읽고, 조금 고치고, 실행해보는 감각**을 목표로 함.
#
# * **객체지향 프로그래밍(Object-Oriented Programming)** 지원 (cf. 절차지향 언어)
#
# * 실습은 **Google Colab** 환경에서 진행합니다.
#   - 설치 없이 브라우저에서 바로 실행
#   - 에디터 + 실행 환경이 하나로 합쳐진 도구
#
# > 참고 자료 (선택):
# > *점프 투 파이썬* (위키독스, 무료)
# > https://wikidocs.net/book/1

# %% [markdown]
# # **Google Colab 파이썬 실습 환경**
#
# * **Google Colab**은
#   웹 브라우저에서 바로 파이썬을 실행할 수 있는 실습 환경입니다.
#
# * 오늘은
#   - 별도 프로그램 설치 하지 않습니다.
#   - 복잡한 설정없이 바로 실습을 시작합니다.
#
# * Colab을 사용하는 이유
#   - 인터넷만 있으면 어디서든 실행 가능
#   - 코드 작성과 실행을 **같은 화면**에서 바로 확인
#   - 실습 위주 수업에 가장 적합한 환경
#
# * 파이썬에는 매우 많은 기능과 라이브러리가 있지만,
#   **오늘은 그중 일부만 사용합니다.**
#
# * 오늘의 목표
#   - 파이썬 문법을 “다 외우는 것"이 아니라,
#   - **코드를 읽고, 조금 고치고, 실행해보는 감각**을 익히는 것입니다.
#
# > 오늘 실습이 끝나면
# > “아, 이런 식으로 쓰는 언어구나” 정도만 느껴도 충분합니다.

# %% [markdown]
# # **Google Drive 연동(마운팅)**
#
# * 오늘 수업에서는 **Google Drive 연동 없이도** 실습을 진행할 수 있습니다.
#   - 간단한 문법 연습
#   - 코드 실행 결과 확인
#   → 이 정도는 **연동 없이 충분**합니다.
#
# * 다만, 앞으로 다음과 같은 작업을 할 때는 Drive 연동이 필요해집니다.
#   - 외부 파일 불러오기 (`.csv`, `.xlsx` 등)
#   - 크롤링 결과나 분석 데이터를 저장하기
#   - 여러 개의 노트북 파일을 체계적으로 관리하기

# %%
# (여긴 코드셀)
# 아래 코드는 Google Drive를 Colab에 연결(마운트)하는 예시입니다.
# 지금은 반드시 실행하지 않아도 됩니다.

# "#"으로 시작하는 줄은 '주석'이며 실행되지 않습니다.
# (단축키: Ctrl + /)

from google.colab import drive
drive.mount('/content/drive')  # Drive가 /content/drive 경로에 연결됨

# %% [markdown]
# * 참고: **주석(comments)**: 코드 내 설명/메모를 작성할 때 사용
#   - 실행 시 무시됨
#   - `#` 해시 기호로 시작
#   - Colab 단축키: **Ctrl + /**

# %% [markdown]
# # **파이썬 코드 읽는 법**
#
# * 파이썬 코드는 보통 이런 형태로 읽습니다.
#
# * **객체.동작(필요한 정보)**
#   → 객체(특정 자료)에 대해 동작(함수)을 적용하고,
#   필요하면 추가 정보(인자)를 함께 전달합니다.
#   (보통 **객체.함수(인자)** 형태로 사용)
#
# * 예를 들면,
#   - 문자열 객체에 대해
#   - “나누기”라는 동작을 시키고
#   - 기준이 되는 값을 함께 전달합니다.
#
# * 지금은 용어를 외우지 않아도 됩니다.
#   - 중요한 건 **어디에 점(.)이 붙는지**
#   - 그리고 **괄호 안에 무엇이 들어가는지**입니다.
#
# * 아래 예제를 실행하면서 감각만 익혀봅시다.

# %%
# 예제
# 문자열 객체
text = "뉴진스는 대한민국 5인조 걸그룹이다."

# 출력
print(text)

# 문자열에 대해 '나누기' 동작 수행
result = text.split(" ")

print(result)
print(type(result))

# 원래 문자열은 변하지 않음
print(text)

# %% [markdown]
# # **코드 실행 방법 (Google Colab)**
#
# * 현재 코드셀 실행: **Ctrl + Enter**
# * 현재 코드의 부분 실행: **Ctrl + Shift + Enter**
# * 실행 취소(Undo): **Ctrl + z**
# * 저장: **Ctrl + s**
# * 주석 처리/해제: **Ctrl + /**
#
# 💡 코딩 입력이 이상하게 될 경우 → 모니터 오른쪽 하단 **입력기 설정** 확인
#   - '한컴 입력기' **[ㅎ]** 로 되어 있으면 정상 작동이 안될 수 있음
#   - 반드시 '마이크로소프트 입력기' **[한]** 으로 설정

# %% [markdown]
# # **값에 이름 붙이기: 변수**
#
# * 파이썬에서는 값을 만들고,
#   그 값에 **이름을 붙여서** 사용합니다.
#
# * 이때 붙인 이름을 **변수**라고 부릅니다.
#   - 예: `x = 1` → 변수 `x`는 정수 객체 `1`을 참조함

# %% [markdown]
# # **다양한 자료형**
# * 객체의 자료는 다양한 **자료형(data type)** 으로 존재 (총 7가지 기본형)
#   - **기본 자료형**: 문자열(`str`), 숫자형(`int`, `float`), 불형(`bool`)
#   - **복합 자료형**: 리스트(`list`), 사전(`dict`), 튜플(`tuple`), 집합(`set`)
#
# * 객체의 자료형은 **type() 함수**로 확인 가능
#   - 예:
#     ```python
#     type(1)        # <class 'int'>
#     type("1")      # <class 'str'>
#     type(True)     # <class 'bool'>

# %%
# 문자열 값을 만들고 이름 붙이기
text = "뉴진스는 대한민국 5인조 걸그룹이다."

print(text)
print(type(text))

# %% [markdown]
# # **자료형 다루기**
#
# * **기초 문법**
#   - 연산자: `+`, `-`, `*`, `/`, `//`, `%` 등
#   - 인덱싱(indexing): 특정 요소를 가리킴
#   - 슬라이싱(slicing): 특정 구간을 잘라냄
#   - 함수와 클래스: 자료 또는 요소를 생성, 수정, 변형할 때 사용

# %% [markdown]
# ## **문자열 (string) 자료형**
#
# * 문자열은 **글자와 문장 같은 텍스트 데이터**를 다루는 자료형입니다.
# * 기사 제목, 문장, 문단 등 대부분의 텍스트는 문자열입니다.
# * 따옴표로 감싸서 표현합니다.
# * 문자열 예시
#   - `'Hello'`, `"KHU"`, `'NewJeans'`, `"DHL"`
# * 여러 줄 문자열: 따옴표 3개(`'''` 또는 `"""`)로 감싸서 작성
#   ```python
#   text = """여러 줄에 걸쳐
#   문자열을 작성할 수 있습니다."""

# %%
s = "안녕하세요"
print(s)
print(type(s))

# %%
s2 = '뉴진스가 "안녕하세요"라고 인사했다'
print(s2)

# %%
# 문자열 자료가 두 줄 이상이면 따옴표 연속 3개를 앞뒤로 삽입
# docstring(document string): 몇줄에 걸친 문자열

s_long = '''I don't know what we've done
되돌아가긴 싫어, もう知っている
Don't know what we've been sold
見つけられるよ, so it's sure (come on)'''

s_long

# 화면상 자료의 출력함수: print() > 줄바꿈 표시(\n) 없게 해줌
print(s_long)

# %% [markdown]
# ### 문자열 연산
#
# * 문자열은 **덧셈(+)** 과 **곱셈(*)** 연산이 가능
#   - `+` : 문자열 이어붙이기 (concatenation)
#   - `*` : 문자열 반복하기 (repetition)

# %%
print("안녕하세요" + " 뉴진스입니다")
print("Hi " * 3)

# %% [markdown]
# ### 문자열 길이

# %%
s = "안녕하세요"
print(len(s))

# %%
# 여러 줄 문자열의 길이는?
s_long = '''I don't know what we've done
되돌아가긴 싫어, もう知っている
Don't know what we've been sold
見つけられるよ, so it's sure (come on)'''

# %% [markdown]
# ### 문자열 인덱싱과 슬라이싱
#
# * 문자열은 **0부터 번호를 매겨** 접근합니다.
# * 대괄호 [ ]를 사용합니다.

# %%
text = "KHU Python"
print(text[0])
print(text[-1])

# %%
print(text[:3])
print(text[4:])

# %%
# 슬라이싱 이후에도 원본은 변하지 않음 (불변성)
print(text)        # 원본 문자열 그대로 유지

# %% [markdown]
# ###  문자열 관련 주요 함수
#
# * 파이썬 문자열은 **내장 함수**를 통해 다양한 처리가 가능 (별도 라이브러리 필요 없음)
# * 문자열은 **immutable(불변) 자료형** → 원본 문자열은 바뀌지 않고 **새로운 문자열**을 반환함
#
# * 주요 함수 예시
#   - `len()` : 문자열 길이 반환
#   - `type()` : 자료형 확인
#   - `count()` : 특정 문자열이 등장하는 횟수
#   - `find()` : 특정 문자열이 처음 나타나는 위치 (없으면 -1 반환)
#   - `index()` : 특정 문자열이 처음 나타나는 위치 (없으면 에러 발생)
#   - `upper()` : 모두 대문자로 변환
#   - `lower()` : 모두 소문자로 변환
#   - `strip()` : 앞뒤 공백 제거
#   - `split()` : 구분자를 기준으로 문자열 나누기 → 리스트 반환
#   - `join()` : 리스트 요소를 특정 구분자로 이어붙이기
#   - `replace()` : 특정 문자열을 다른 문자열로 교체
#
# * 문자열 처리에서 가장 많이 쓰는 함수
#   - `split()` : 문자열을 나누기
#   - `replace()` : 문자열 바꾸기
#   - `strip()` : 앞뒤 공백 제거
#
# “뉴스 크롤링, 설문 데이터 전처리에서 제일 많이 씁니다”

# %%
text = "  AI makes media smarter  "

print(text.strip())
print(text.replace("media", "advertising"))
print(text.split())

# %% [markdown]
# ### **문자열 포맷팅 (String Formatting)**
#
# * 문자열 안에 값을 넣고 싶을 때 사용합니다.
#
#    - (1) format() 문자열 함수사용하기
#
#    - (2) 포맷코드 사용하기: %s(문자열), %d(정수), %f(실수) 등
#
#    - (3) **f-string(f 문자) 언어문법(신택스) 사용하기(매우간단)**

# %%
name = "하니"
score = 91.456

print(f"{name}의 점수는 {score:.2f}점입니다")

# %% [markdown]
# ## **숫자형 (numeric) 자료형**
#
# * 숫자형은 **계산을 위한 자료형**입니다.
# * 파이썬의 숫자형은 크게 두 가지입니다.
#   - **정수형 (int)** : 1, 2, 3 …
#   - **실수형 (float)** : 1.5, 3.14 …

# %% [markdown]
#  ### 숫자 vs. 문자열

# %%
i = 5
print(i, type(i))

i = "5"
print(i, type(i))

# 겉모습이 같아도, 자료형이 다르면 전혀 다른 값!

# %% [markdown]
# ### 자료형 연산

# %%
i = int("5")
print(i, type(i))

f = float("2.5")
print(f, type(f))

# %% [markdown]
# ### 숫자 연산 (자주 쓰는 것만)

# %%
print(5 + 5)
print(10 / 2)   # 나누기 → 항상 실수
print(7 // 3)   # 몫
print(7 % 3)    # 나머지

# %% [markdown]
# ### 축약 연산자: 본래 값에 일정량 더하기
#
# * 빼기, 곱하기, 나누기도 가능

# %%
x = 2
x += 1
print(x)

# %% [markdown]
# ## **불(bool) 자료형**
#
# * 불(bool)은 **참(True)과 거짓(False)**을 나타내는 자료형입니다.
# * 파이썬에서 조건을 판단할 때 사용됩니다.
# * 모든 `if` 문은 **결국 True 또는 False를 묻습니다.**

# %% [markdown]
# ### 비교 결과는 True/ False

# %%
print(2 > 1)
print(type(2 > 1))

# 비교의 결과는 항상 True 아니면 False!

# %% [markdown]
# ### 논리연산자 - and/ or

# %%
print((2 > 1) and (0 > 1))
print((2 > 1) or (0 > 1))

# %% [markdown]
# ### 포함 여부 판단 - in + 객체(매우 중요)

# %%
a = "안녕하세요. 뉴진스입니다"

print("뉴진스" in a)
print("하니" in a)

# %% [markdown]
# ### if 문 맛보기

# %%
if "뉴진스" in a:
    print("a 문자열 안에 뉴진스가 있습니다")
else:
    print("a 문자열 안에 뉴진스가 없습니다")

# if문은 조건이 True인지 False인지만 묻는 문장

# %% [markdown]
# ## **리스트 (list)**
#
# * 리스트는 **여러 개의 값을 한 번에 담는 자료형**입니다.
# * 대괄호 `[ ]`를 사용하고, 쉼표로 값을 구분합니다.
# * 리스트는 **순서가 있고**, **값을 바꿀 수 있습니다.**
# * 리스트는 **가변 자료형(mutable)**

# %% [markdown]
# ### 리스트 생성

# %%
lst_null = []                # 빈 리스트 생성 (중요)

members = ["하니", "해린", "민지", "혜인", "다니엘"]
heights = [162, 165, 169, 170, 165]

print(members)
print(heights)

# %% [markdown]
# ### 리스트 인덱싱
# * 리스트에서 값 꺼내기
# * 리스트의 각 요소는 **0부터 번호**를 가집니다.

# %%
print(members[0])
print(members[-1])

# %% [markdown]
# ### 리스트 수정(중요!)

# %%
members[-1] = "카리나"
print(members)

# 문자열과 달리, 리스트는 값을 직접 바꿀 수 있습니다.

# %% [markdown]
# ### 리스트 슬라이싱
# * 리스트의 부분집합을 추출 (형식: `리스트이름[start:end]`)

# %%
print(members[1:4])
print(members[3:])

# %% [markdown]
# ### 리스트 길이와 간단한 계산(총합과 평균)

# %%
nums = [10, 20, 30, 40]

print(len(nums))
print(sum(nums))
print(sum(nums) / len(nums))

# %% [markdown]
# ### 자주 쓰는 리스트 메서드
#   - `append()` : 리스트 맨 뒤에 요소 추가
#   - `remove()` : 특정 값 삭제

# %%
members.append("카리나")
print(members)

members.remove("민지")
print(members)

# %% [markdown]
# ## **튜플 (tuple)**
#
# * 튜플은 **여러 값을 한 번에 담는 자료형**입니다.
# * **소괄호 ( )** 로 감싸고, 각 요소는 쉼표(,)로 구분
# * 리스트와 거의 같지만, **값을 바꿀 수 없습니다. (immutable)**
# * 즉, **고정된 데이터**를 담을 때 사용합니다.
#
# * 예:
#   - 좌표 (x, y)
#   - 요일 이름
#   - 바뀌면 안 되는 기준값
#
# * “리스트와 거의 같은데,
# 절대 바뀌면 안 되는 데이터를 담을 때 쓰는 자료형”

# %%
tp_null = () # 비어있는 튜플 생성

members = ("하니", "해린", "민지", "혜인", "다니엘")

print(members)
print(members[0])
print(members[-1])

# “읽는 건 리스트랑 거의 똑같음”

# %% [markdown]
# ### 튜플은 수정 불가!

# %%
# 아래 코드는 실행하면 에러가 납니다 (튜플은 수정 불가)
members[0] = "카리나"

# 리스트: 자주 바뀌는 데이터
# 튜플: 절대 바뀌면 안 되는 데이터

# %% [markdown]
# 지금까지는
# **순서로 값을 찾는 자료형**이었습니다.
#
# 이제부터는
# **이름(키)로 값을 찾는 자료형**을 봅니다.
#
# ---
#
# ## **사전 (dictionary)**
#
# * 사전은 **키(key)와 값(value)** 이 한 쌍으로 이루어진 자료형입니다.
# * 인덱스 번호 대신 **키를 사용해 값을 찾습니다.**
# * 생성 방법 : **중괄호 { }** 로 감싸고, 요소들은 쉼표(,)로 구분
# * 데이터의 **검색, 추가, 수정**이 잦을 때 매우 유용합니다.

# %% [markdown]
# ### 딕셔너리 생성과 조회

# %%
#  사전 생성하기
dct = {} # 빈 사전생성
type(dct)

# %%
country = {
    "한국": "서울",
    "미국": "워싱턴",
    "중국": "베이징"
}

print(country["한국"])
print(country["미국"])

# “사전에서는 몇 번째가 아니라, 이름으로 찾습니다.”

# %%
# 데이터 탐색/점검

dct.keys()     # 어떤 key(코드)가 있는지? dct라는 사전의 모든 key 출력
dct.values()   # 어떤 value(라벨)가 매핑돼 있는지? dct라는 사전의 모든 value 출력
dct.items()    # 전체 매핑 쌍을 보고 싶을 때? dct라는 사전의 모든 key, value 쌍 출력

# %%
# 아래 코드는 실행하면 에러가 납니다
country["일본"]

# “없는 키를 찾으면 에러가 납니다.”

# %% [markdown]
# ### 딕셔너리 = 코드북(매핑 테이블)
#
# * 코드 ↔ 의미를 연결할 때 자주 사용됩니다.
# * 실제 데이터 분석과 미디어 연구에서 매우 흔합니다.

# %%
press_map = {
    101: "조선일보",
    102: "동아일보",
    103: "중앙일보",
    201: "한겨레",
    202: "경향신문"
}

print(press_map[101])
print(press_map[202])

# for 문을 사용할 수 있음
for code, name in press_map.items():
    print(code, ':', name)

# %% [markdown]
# ### 딕셔너리 값 수정과 추가 그리고 삭제

# %%
country["한국"] = "세종"
country["영국"] = "런던"

print(country)

# dct라는 사전에서 "영국"과 "런던" 키와 값 쌍을 동시에 삭제가능
del dct["영국"]
dct

# %% [markdown]
# ## **집합 (set)**
#
# * 집합은 **중복을 허용하지 않는 자료형**입니다.
# * **순서가 없어서 인덱싱이 불가능**합니다.
# * 주로 **중복 제거**나 **공통 요소 찾기**에 사용합니다.

# %% [markdown]
# ### 집합 생성 & 중복 제거(핵심)

# %%
# 빈 집합 생성 방법
st = set()
print(type(st))        # <class 'set'>

lst = ["하니", "해린", "민지", "혜인", "다니엘", "하니"]

unique_members = set(lst)
print(unique_members)

# 중복이 자동으로 사라짐

# %% [markdown]
# ### 집합 --> 리스트

# %%
unique_list = list(unique_members)
print(unique_list)

#“전처리할 때 정말 많이 쓰는 패턴!”

# %% [markdown]
# ### 집합으로 공통 요소 찾기

# %%
# 교집합 예시

뉴진스 = {"하니", "해린", "민지", "혜인", "다니엘", "방시혁"}
BTS    = {"RM", "진", "슈가", "제이홉", "지민", "뷔", "정국", "방시혁"}

print(뉴진스 & BTS)

# 두 집합에 공통으로 들어 있는 요소만 남습니다.

# %% [markdown]
# ## **제어문 (if, while, for)**
#
# * 제어문은 **조건이나 반복에 따라 코드의 실행 흐름을 바꾸는 문법**입니다.
# * 대표적인 제어문:
#   - **if 문**: 조건이 참일 때만 실행
#   - **while 문**: 조건이 참으로 유지되는 동안 반복
#   - **for 문**: 자료형의 요소를 하나씩 꺼내 반복 처리
#
# * 문장들이 프로그램의 흐름을 "제어"하기 때문에 **제어문**이라고 부름

# %% [markdown]
# ## **if 문 (조건문)**
#
# * 조건의 참(True) / 거짓(False)에 따라 실행 여부를 결정
# * 기본 구조:
#
#     if 조건:
#         실행할 코드
#     else:
#         실행할 코드
#
# * 반드시 **콜론(:)** 과 **들여쓰기**가 필요
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 기본 if - else 문
# * if문 + 비교연산자

# %%
score = 85

if score >= 60:
    print("합격입니다.")
else:
    print("불합격입니다.")

# “if 문은 조건이 참이면 실행, 아니면 건너뜁니다.”

# %% [markdown]
# * if문 + in 연산자(자료형 연결)

# %%
members = ["하니", "해린", "민지", "혜인", "다니엘"]

if "하니" in members:
    print("하니는 뉴진스 멤버입니다.")
else:
    print("하니는 뉴진스 멤버가 아닙니다.")

# %% [markdown]
# ### 기본 if - elif - else 문

# %%
# if + 조건1:
# elif + 조건2:

score = 85 #참고: score = int(input("성적을 입력하세요: "))

if score >= 90:
    print("A 학점")
elif score >= 80:
    print("B 학점")
else:
    print("C 학점 이하")

# 위에서 부터 순서대로 검사

# %% [markdown]
# ## **while 문 (반복문)**
#
# * while 문은 **조건이 참(True)인 동안** 코드를 반복 실행합니다.
# * 조건이 거짓(False)이 되면 반복이 종료됩니다.
# * 조건을 바꾸지 않으면 **무한 반복**이 됩니다.
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 가장 기본적인 while (핵심 예제)

# %%
# while 문은 “언제 끝날지 조건으로만 아는 반복

x = 1

while x < 10:
    print(x)
    x += 1

# “while 문에서는 조건을 내가 직접 바꿔줘야 합니다.”

# %% [markdown]
# ### 무한 반복과 break

# %%
while True:
    print("한 번만 실행됩니다.")
    break

# break는 반복을 강제로 끝내는 탈출구

# %% [markdown]
# ### continue는 ‘이번만 건너뛰기’

# %%
x = 0

while x < 5:
    x += 1
    if x == 3:
        continue
    print(x)

# %% [markdown]
# ## **제어문(3) – for문 (반복문)**
#
# * for문은 **시퀀스(리스트, 문자열 등)**의 요소를
#   **하나씩 꺼내며 반복 실행**하는 반복문입니다.
# * 기본 형태:
#
#     for 변수 in 반복가능한_객체:
#         실행할 코드
# * “for문은 ‘각각 하나씩’ 처리하는 문법입니다.”
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 왜 for문이 필요한가?(비효율 예시)

# %%
members = ["하니", "해린", "민지", "혜인", "다니엘"]

print(members[0])
print(members[1])
print(members[2])
print(members[3])
print(members[4])

# 사람이 하기엔 너무 비효율적

# %% [markdown]
# ### for문으로 리스트 순회 (핵심)

# %%
for name in members:
    print(name)

# members 안의 요소가 하나씩 name에 들어오고, 그때마다 위 코드가 실행됨

# %% [markdown]
# ### for문 + f-string (가장 많이 쓰는 패턴)

# %%
for name in members:
    print(f"{name}는 뉴진스 멤버입니다.")

# %% [markdown]
# ### for문 + if문
# * 반복 중에 **조건에 따라 다른 처리**를 할 수 있습니다.

# %%
# 점수평가(for + if의 대표 예제)
# 각 점수를 하나씩 꺼내서, 조건을 검사합니다.

scores = [95, 55, 71, 83]

for score in scores:
    if score >= 80:
        print("귀가")
    else:
        print("재시")

# %% [markdown]
# ### 결과를 새로운 리스트에 담기 (중요!)

# %%
시험점수 = [95, 55, 71, 83]
성적평가 = [] # 빈리스트 생성

for 점수 in 시험점수:
    if 점수 >= 80:
        성적평가.append("귀가") #append 함
    else:
        성적평가.append("재시")

print(성적평가)
# ['귀가', '재시', '재시', '귀가']

# %% [markdown]
# ### range 함수
# * 숫자 범위를 만들어 for문과 함께 사용

# %%
# range 기본사용
for i in range(5):
    print(i)

# %%
# 리스트 길이에 맞춰 반복
# 인덱스가 필요할때만 이렇게 사용

members = ["하니", "해린", "민지", "혜인", "다니엘"]
for i in range(len(members)):
    print(members[i])

# %% [markdown]
# ### 리스트 컴프리헨션 (List Comprehension)
#
# * for문으로 **새 리스트를 만드는 간단한 방법**
# * 각 요소에 같은 변화를 줘 **리스트 전체를 한 번에 변형**
# * 기본 형태:
#
#     [변형식 for 요소 in 리스트]
#
# * 지금은 **읽을 수만 있으면 충분**합니다.
#
#
# 이제부터는 이 반복되는 코드를
# 이름 붙여서 재사용하는 방법,
# 즉 함수(function) 를 보겠습니다.”

# %% [markdown]
# * for문 방식 → 컴프리헨션 비교 (핵심)

# %%
# for문을 사용한 기존 방식
lst_numeric = [23, 52, 98, 31]

result = []
for i in lst_numeric:
    result.append(i + 100)

print(result)

# %%
# 리스트 컴프리헨션 (같은 작업을 한 줄로 재구성)
result2 = [i + 100 for i in lst_numeric]
print(result2)

# %% [markdown]
# * 조건이 들어간 컴프리헨션

# %%
# 조건이 들어간 리스트 컴프리헨션 (맛보기)
시험점수 = [95, 55, 71, 83]

성적평가 = ["귀가" if 점수 >= 80 else "재시" for 점수 in 시험점수]

print(성적평가)

# 지금은 읽기만 하고 나중에 익숙해지면 됨

# %% [markdown]
# ### 참고: Input() 함수
#
# - 사용자로부터 값을 입력받을 때 사용
# - 입력값은 **항상 문자열(str)** 형태로 반환
# - 숫자가 필요하다면 `int()` 또는 `float()`로 변환해야 함

# %%
# 이름 입력받기
name = input("이름을 입력하세요: ")
print("입력한 이름:", name)

# 나이 입력받기 (문자열 → 정수 변환)
age = int(input("나이를 입력하세요: "))
print("내년 나이:", age + 1)

# %% [markdown]
# ### 참고: 예외 처리(try/except)
# - **예외(Exception)**: 코드 실행 중에 발생하는 오류
# - **프로그램이 중간에 멈추지 않도록, 에러를 처리하는 방법이 필요**
# - `try` 블록에 에러가 발생할 수 있는 코드를 작성
# - `except` 블록에 에러가 발생했을 때 실행할 코드를 작성

# %%
#"뉴진스 멤버 확인 프로그램 (예외 처리 포함)"
# 리스트에서 특정 이름이 있는지 확인하면서,예외가 발생해도 프로그램이 멈추지 않고 계속 실행되도록 만든 예제

members = ["하니", "해린", "민지", "혜인", "다니엘"]

try: # 블록 안에서 코드를 실행 - 실행중 오류가 발생하면 멈추지 않고 excpet 블로으로 이동
    name = int(input("이름을 입력하세요: "))
    if name in members:
        print(f"{name}는 뉴진스 멤버입니다.")
    else:
        print(f"{name}는 뉴진스 멤버가 아닙니다.")
except Exception as e: # 모든 에러를 잡아 변수 e에 담는다는 뜻
    print("에러가 발생했습니다:", e)

# %% [markdown]
# * for문을 쓰다 보니
#   **비슷한 구조의 코드가 계속 반복됩니다.**
#
# * 이제부터는
#   이런 코드를 **이름 붙여서 재사용하는 방법**,
#   즉 **함수(function)** 를 보겠습니다.

# %%
## **함수 (function)**

* 함수는 **입력값을 받아서**
  **어떤 작업을 한 뒤**
  **결과를 돌려주는 도구**입니다.

* 비유:
  - 수학 함수: y = 2x + 1
  - 과일(입력) → 믹서기(함수) → 주스(출력)

* 함수는 **입력 → 작업 → 출력** 구조로 동작합니다.
* 반복되는 코드를 재사용할 때 사용합니다.

# %% [markdown]
# ## **함수 (function)**
#
# * 함수는 **입력값을 받아서**
#   **어떤 작업을 한 뒤**
#   **결과를 돌려주는 도구**입니다.
#
# * 비유:
#   - 수학 함수: y = 2x + 1
#   - 과일(입력) → 믹서기(함수) → 주스(출력)
#
# * 함수는 **입력 → 작업 → 출력** 구조로 동작합니다.
# * 반복되는 코드를 재사용할 때 사용합니다.
# * 함수 정의와 호출 시, 반드시 **콜론(:)** 과 **들여쓰기** 유의
#
# *   아래 **프로그래밍 함수**의 구조 참조
# * def: 함수 정의 키워드
# * 매개변수(parameter): 입력값을 받는 변수
# * return: 함수의 결과값 반환
# * 👉 return이 있으면 “결과를 돌려주는 함수”
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 가장 기본적인 함수 예제

# %%
# 아래 함수는 숫자 2개를 받아서 더한 결과를 돌려줍니다
def add(x, y):
    result = x + y
    return result

add(3, 5)

# %% [markdown]
# ### 함수 재사용의 의미

# %%
add(4000, 5)
add(10, 20)

# %% [markdown]
# ### 조건문 + 함수 (핵심 실전 예제)

# %%
members = ["하니", "해린", "민지", "혜인", "다니엘"]

def 뉴진스_member_detect(name):
    if name in members:
        return f"{name}는 뉴진스 멤버입니다."
    else:
        return f"{name}는 뉴진스 멤버가 아닙니다."

# %%
뉴진스_member_detect("하니")
뉴진스_member_detect("이두황")

# 👉 for문에서 만들던 로직을 함수로 묶은 구조

# %% [markdown]
# ### print vs return
#
# * print: 화면에 보여주기만 함
# * return: 결과를 돌려줘서 **다른 코드에서 재사용 가능**
#
# → 함수에서는 **return을 더 많이 사용**

# %% [markdown]
# ### 입력값은 없고, return만 있는 함

# %%
def 인사():
    return "안녕하세요"

인사()

# 👉 “입력이 없어도 함수는 만들 수 있다”

# %% [markdown]
# * 함수까지 배웠다면,
#   이제는 **관련된 함수와 데이터를 한 덩어리로 묶는 방법**을 봅니다.
#
# * 이것이 바로 **클래스(class)** 입니다.

# %% [markdown]
# ## 클래스(class)
#
# * 클래스는 **객체를 만들기 위한 설계도**입니다.
#   - 붕어빵 틀 → 클래스
#   - 붕어빵 → 객체(인스턴스)
#
# * 객체(object, instance):
#   클래스로부터 실제로 만들어진 대상
#
# * 메서드(method):
#   클래스 안에 들어 있는 함수
#   → 객체가 할 수 있는 행동
#
# * 생성자(`__init__`):
#   객체가 만들어질 때 **자동으로 실행되는 함수**
#   → 초기값 설정

# %% [markdown]
# ### 클래스 기본 구조

# %%
class 클래스이름:
    def __init__(self, 매개변수):
        # 생성자 (constructor)
        self.속성 = 매개변수

    def 메서드이름(self):
        # 메서드 (method)
        동작 코드

# 👉 self = “이 객체 자신”

# %% [markdown]
# ### 아주 단순한 계산기 클래스

# %%
# 이 클래스는 숫자 두 개를 기억하고, 더하고, 곱할 수 있는 객체 설계도
# Calculation 클래스는
# - 값(n1, n2)을 **가지고 있고**
# - add(), mul()이라는 **행동을 할 수 있는 객체**를 만듭니다.


class Calculation:                      # 클래스는 대문자로("C"aculation), 객체는 소문자로
    def __init__(self, n1, n2):         #  __init__(self, n1, n2)는 생성자(constructor) 표시.
        self.n1 = n1                    # 아래에 객체가 생성될 때 이 생성자가 자동으로 호출됨. 객체 속성의 초기화작업 담당
        self.n2 = n2                    # 객체가 생성될 때, 전달된 두 개의 값 n1과 n2를 해당 객체의 속성 self.n1과 self.n2에 저장하여 초기화합니다.
                                        # self는 아래 생성될 객체 자신을 가리킴, 이를 통해 클래스 속성에 접근할 수 있음

    def add(self):                      # 객체가 수행할 동작인 2개의 함수(메서드) 정의: 더하기, 곱하기
        result = self.n1 + self.n2
        return result

    def mul(self):
        result = self.n1 * self.n2
        return result

# %% [markdown]
# ### 객체(인스턴스) 만들기

# %%
# 클래스를 이용해서 특정 속성(8. 5)을 가진 객체(cal1) 생성하기
cal1 = Calculation(8, 5) # 이때 클래스의 생성자인 __init__ 메서드를 자동으로 호출

# %%
# # cal1 객체인 속성인 cal2.n1와 cal2.n2는?
cal1.n1 # 객체의 속성 8
cal1.n2 # 객체의 속성 5

# <클래스, 객체, 속성, 메서드에 대한 설명>
# Calculation 클래스라는 설계도를 사용해 'cal1'이라는 계산기 객체를 하나 만듬
# 'cal1' 객체는 8과 5를 가지고 태어나며(=객체의 속성)
# 클래스의 _init__ 메서드를 자동으로 호출하면서 n1과 n2에 각각 8과 5가 전달되며 이 값들은 self.n1과 self.n2에 저장
# 즉, n1과 n2를 받아서, 객체(cal)의 속성인 self.n1과 self.n2를 초기화하는 역할
# 클래스의 메서드인 add()과 mul()같은 동작을 수행할 수 있음

# %% [markdown]
# ###객체가 메서드를 수행

# %%
# 호출된 객체(cal1)가 수행할 더하기,곱하기 동작 메서드의 결과는?
cal1.add()         # 13
cal1.mul()         # 40

# 함수를 그냥 호출하는게 아니라, 객체가 수행합니다.

# %% [markdown]
# ### 같은 클래스로 부터 객체는 여러개 만들 수 있음

# %%
# 👉 같은 설계도로 다른 객체(cal2) 생성

cal2 = Calculation(10, 2)

cal2.add()
cal2.mul()

# %% [markdown]
# ### 현실적인 예제 – 멤버 클래스

# %%
# 클래스를 이용해서 뉴진스 멤버의 이름과 나이를 바탕으로 자기소개를 생성하는 객체를 만드는 예
members = ["하니", "해린", "민지", "혜인", "다니엘"]

class Member:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def introduce(self): # 객체가 수행할 동작인 자기소개 메서드
        return f"저는 {self.name}, {self.age}살입니다."

# %% [markdown]
# * 멤버 객체 생성 & 호출

# %%
# 멤버 한 명이 객체가 됩니다.
m1 = Member("하니", 20) # 객체(m1) 생성하고 호출: 속성은 "하니"와 20
m2 = Member("해린", 21) # 객체(m2) 생성하고 호출: 속성은 "해린"과 21


# 호출된 객체(m1, m2)가 수행할 동작인 자기소개 메서드 호출하기
m1.introduce()
m2.introduce()

# %% [markdown]
# 1. 클래스는 설계도다
# 2. 객체는 설계도로 만든 실제 대상이다
# 3. 객체는 속성과 메서드를 함께 가진다

# %% [markdown]
# # 모듈 · 패키지 · 라이브러리

# %% [markdown]
# ## 모듈 (module)
#
# ### 모듈이란?
#
# - 함수, 변수, 클래스 등을 모아 둔 **파이썬 파일 하나 (.py)**
# - 자주 쓰는 기능을 한 번 만들어 두고
#   👉 필요할 때마다 `import` 해서 재사용
# - 파이썬에는 이미 많은 **기본 모듈**이 포함되어 있음
#
# > **모듈 = 기능을 담아 둔 파이썬 파일 하나**

# %% [markdown]
# ### 이미 만들어진 모듈 사용하기
# * 1️⃣ 모듈 전체 불러오기

# %%
# random 모듈을 사용해서 랜덤 숫자를 만들기
import random

print(random.randint(1, 10))

# random : 모듈 이름
# randint : random 모듈 안에 있는 함수
# . : “~안에 있는” 이라는 의미

# %% [markdown]
# * 2️⃣ 특정 함수만 불러오기

# %%
 # math 모듈에서 제곱근을 계산하는 함수를 불러와 사용

from math import sqrt

print(sqrt(9))   # 9의 제곱근

# 자주 쓰는 함수만 가져오면 코드가 짧아짐
# 대신 함수의 출처를 잊기 쉬움 → 초보자는 import 모듈 방식도 충분히 좋음

# %% [markdown]
# ### 내가 만든 모듈 사용하기 (코랩 기준)
# * 예시: mymodule.py 파일 불러오기(이 파일은 Drive에 저장되어 있다고 가정)
# * 제공한 파일을 작업폴더("/content/drive/MyDrive/mypython")에 저장
# * 여기에선 코랩과 drive의 마운팅, 즉 연동이 꼭 필요함

# %%
# 연동하기

from google.colab import drive
drive.mount('/content/drive')


# 먼저 모듈이 있는 폴더를 지정
# 모듈인 sys 모듈을 사용하여 Python의 모듈 검색 경로에 새로운 디렉터리를 추가하는 코드
import sys
sys.path.append('/content/drive/MyDrive/mypython') # 모듈이 있는 작업폴더로 이동
# print(sys.path)  # 추가된 경로를 출력하여 확인

# %%
# mymodule.py 파일 내용
# # mymodule.py: 'add'와 'sub'라는 두가지 함수가 있는 파이썬 파일
def add(a, b):
    return a + b

def sub(a, b):
    return a - b

# %% [markdown]
# * 1️⃣ 모듈 전체 불러오기

# %%
import mymodule

print(mymodule.add(3, 4))
print(mymodule.sub(8, 4))


# ✔️ mymodule.add()
# → mymodule 안에 있는 add 함수를 호

# %% [markdown]
# * 2️⃣ 특정 함수만 불러오기

# %%
from mymodule import add, sub

print(add(4, 2))
print(sub(4, 2))

# %% [markdown]
# ## 패키지(package)
#
# ### 패키지란?
#
# - 여러 개의 **모듈(.py 파일)** 을 폴더 구조로 묶어 놓은 것
# - 모듈이 많아질 때 **체계적으로 관리**하기 위해 사용
# - 보통 폴더(디렉터리) 안에 모듈들이 들어 있음
#
# > **패키지 = 모듈들을 모아 둔 폴더**

# %% [markdown]
# ### 패키지의 구조 예시: game 패키지(개념용)
#
# *   아래와 같은 디렉터리 구조를 가진 game이라는 패키지가 있다고 가정
#
# *   이 구조에서 game은 루트 패키지, sound와 graphics는 서브 패키지(=하위 폴더)
#
# *   echo.py와 render.py는 각각 sound와 graphics 패키지 안에 있는 모듈(=파일)
#
# *  sound 하위폴더아래 echo.py 파일(모듈) 안에 echo_test() 함수가 있다고 가정

# %%
# 예시 구조:

game/
 ┣ __init__.py
 ┣ sound/
 ┃ ┣ __init__.py
 ┃ ┗ echo.py
 ┣ graphics/
 ┃ ┣ __init__.py
 ┃ ┗ render.py

# - `game` → 패키지
# - `sound`, `graphics` → 서브 패키지
# - `echo.py`, `render.py` → 모듈

# %% [markdown]
# ### 패키지에서 함수 불러오기(예시)
#
# *   특정 모듈에서 함수 불러오기:(아래 코드셀은 작동안함. 예시일뿐)

# %%
# 위 game 패키지에서 함수 불러오기:
# echo.py라는 모듈이 있고, 이 모듈 안에 echo_test()라는 함수가 있다고 가정
from game.sound.echo import echo_test  # game 패키지의 sound 서브패키지의 하위폴더_에서 echo 모듈에서 echo_test 함수를 직접 불러오기

echo_test()  # echo 모듈 안의 echo_test 함수 호출

# . 은 폴더 → 파일 → 함수로 내려간다는 의미

# 실제 코랩에서는 구조만 이해하면 충분 (직접 구현은 나중에!)

# %% [markdown]
# ## 📚 라이브러리 (library)
#
# ### 라이브러리란?
#
# - 여러 **모듈과 패키지를 묶어 놓은 큰 기능 묶음**
# - 특정 목적(계산, 데이터 분석, 웹 크롤링 등)을 위해 만들어짐
# - 보통 설치해서 사용 (`pip install`)
#
# > **라이브러리 = 패키지 + 모듈들의 큰 묶음**

# %% [markdown]
# ## 🔍 한눈에 정리
#
# - **모듈**: 파이썬 파일 하나
# - **패키지**: 모듈들을 모아 둔 폴더
# - **라이브러리**: 패키지와 모듈을 묶은 큰 기능 세트
#
# > 📌 규모 기준
# > 모듈 → 패키지 → 라이브러리

# %% [markdown]
# ## 💡 지금은 이렇게 이해하면 충분합니다
#
# - 지금 단계에서는
#   👉 *“남이 만들어 둔 코드 묶음을 불러다 쓴다”* 정도면 충분
# - 직접 모듈·패키지를 만드는 것은 **나중에**
# - 다음 실습에서는
#   - `import`
#   - `from ~ import`
#   - 기본 라이브러리 사용에 익숙해지는 것이 목표

# %% [markdown]
# # 파일 쓰기와 불러오기(File I/O)
#
# ### 파일 다루기란?
#
# - 프로그램 실행 중 만들어진 데이터를 **파일로 저장**하거나
# - 이미 저장된 파일을 **다시 불러와 사용하는 작업**
# - 데이터 분석, 크롤링, 로그 저장 등에서 매우 중요
#
# > **파일 처리 = 데이터의 저장과 재사용**

# %% [markdown]
# ## ✍️ 텍스트 파일 쓰기
#
# - `open()` 함수로 파일을 열고
# - `write()` 메서드로 내용을 저장
# - `with` 구문을 사용하면 파일을 자동으로 닫아 줌 (권장)

# %%
# Google Drive 연동 (한 번만 실행)
from google.colab import drive
drive.mount('/content/drive')

# %%
# 텍스트 파일 쓰기 (저장)

mytext = "하니, 해린, 민지, 혜인, 다니엘" # mytext 변수에 문자열 데이터를 저장

with open("/content/drive/MyDrive/mypython/test.txt", "w", encoding="utf-8") as f:
    f.write(mytext)

# open() 함수로 "test.txt" 파일을 생성하거나 열어서, 파일 **쓰기 모드("w")**로 열겠다는 의미.
# f는 열린 파일을 나타내는 파일 객체
# f.write(mytext):  mytext 변수에 저장된 문자열을  test.txt 파일(=f 파일객체)에 그대로 씀

# %% [markdown]
# ## 📖 텍스트 파일 불러오기(읽기)
#
# - 저장된 파일을 읽기 모드 `"r"` 로 열기
# - `read()`를 사용하면 파일 전체를 한 번에 읽음

# %%
# 텍스트 파일 읽기

with open("/content/drive/MyDrive/mypython/test.txt", "r", encoding="utf-8") as f:
    mytext_read = f.read()

print(mytext_read) #저장된 텍스트를 출력

# open() 함수로 "test.txt" 파일을 **읽기 모드("r")**로 염.
# f는 열린 파일을 나타내는 파일 객체
# f.read()를 통해 test.text 파일(=f 파일객체)의 모든 내용을 읽어와 mytext1 변수에 저장

# %% [markdown]
# ## 🔑 파일 열기 모드
#
# - `"w"` : 쓰기 모드
#   → 파일 생성 또는 **기존 파일 덮어쓰기**
# - `"r"` : 읽기 모드
#   → 파일 읽기 (파일 없으면 오류)
# - `"a"` : 추가 모드
#   → 파일 끝에 내용 추가

# %% [markdown]
# ## 📊 CSV 파일이란?
#
# - 값들이 콤마(,)로 구분된 텍스트 파일
# - 표 형태의 데이터를 저장할 때 자주 사용
# - 엑셀, 구글 시트와 호환 가능

# %% [markdown]
# ## 💾 리스트 데이터를 CSV 파일로 저장
# * CSV는 각 항목이 콤마(,)로 구분된 표 형식

# %%
import csv

# CSV 파일에 저장할 데이터(data) 준비(예, 리스트 혹은 리스트의 리스트 형태)
# data는 아직 CSV 형식의 파일이 아님. 단순한 Python 데이터
data = [
    ["Name", "Age", "Grade"],
    ["하니", 21, "A"],
    ["해린", 22, "B"],
    ["민지", 23, "A"],
    ["혜인", 24, "C"],
    ["다니엘", 25, "B"]
]

# CSV 파일을 열고 그 파일에 파이썬 data를 CSV 파일로 저장하는 과정: 쓰기 모드로 열고 저장
with open("/content/drive/MyDrive/mypython/csv_test.csv", "w", newline="", encoding="utf-8") as f: # open() 함수로 "csv_test.csv" 파일을 생성하고 **쓰기 모드("w")**로 연다
    writer = csv.writer(f)  # csv.writer(f)(CSV writer 객체):csv_test.csv(=f 파일 객체)위에 CSV 형식으로 데이터를 기록할 수 있도록 도구를 제공하 CSV writer 객체를 생성. 데이터를 CSV 형식으로 기록할 수 있는 "펜"과 같은 도구
    writer.writerows(data)  # writer 객체를 사용해 Python의 리스트 데이터를 CSV 형식으로 변환한 후, 한 줄씩 파일에 기록하는 함수

# %% [markdown]
# ### 📂 CSV 파일 불러와서 읽기

# %%
import csv

# CSV 파일 불러와서 읽기
with open("/content/drive/MyDrive/mypython/csv_test.csv", "r", encoding="utf-8") as f:
    reader = csv.reader(f) # CSV 파일을 읽기 위한 도구
    for row in reader: #  CSV 파일의 각 줄을 순서대로 읽는 반복문
        print(row)  # 저장된 데이터를 한 줄씩 출력(리스트로 출력)

# %% [markdown]
# ## 🧠 핵심 정리
#
# - 파일 쓰기: `open()` + `"w"` + `write()`
# - 파일 읽기: `open()` + `"r"` + `read()`
# - CSV 파일: 리스트 데이터를 표 형태로 저장
# - `with` 구문 사용 → 파일 관리 실수 방지
#
# > 지금 단계에서는
# > **파일에 저장 → 다시 불러온다**는 흐름만 이해하면 충분

# %% [markdown]
# ## ✅ 오늘 우리가 한 것
#
# - 파이썬 기본 문법 구조 이해
# - 문자열·리스트·사전 등 자료형 다루기
# - 조건문과 반복문으로 흐름 제어
# - 함수와 클래스로 코드 재사용
# - 모듈·라이브러리 불러오기
# - 파일 저장하고 다시 불러오기
#
# 👉 이제 **크롤링 / 데이터 분석 / 자동화**로 바로 확장 가능
